# %%
import os
import pandas as pd
from taxbrain.taxbrain import TaxBrain

# %%
locale_list = [file[0:4] for file in os.listdir("./subnational/cds/") if file.endswith(".log")]
locale_list.sort()

# %%
locale_name_list = [file[0:2].upper()+"-"+file[2:4] for file in os.listdir("./subnational/cds/") if file.endswith(".log")]
locale_name_list.sort()

# %%
reform_url = "github://OFRA-ORG:Tax-Calculator-thru74@tcja/taxcalc/reforms/rec_mar_2025.json"

# %%
year = 2026
output_list = []

for locale, local_name in zip(locale_list, locale_name_list):
    dynamic = TaxBrain(year, year, microdata="TMD", subnational=True, locale=locale, reform=reform_url, behavior={"sub": 0.25, "cg": -3.45})
    dynamic.run(num_workers=3)
    diff = dynamic.weighted_totals("combined", xtot=0)
    out = round(diff.loc['Difference', year]*1e-6)

    df_base_full = pd.concat([dynamic.base_calc, getattr(dynamic.base_records, 'WT')], axis=1)
    df_base = df_base_full
    df_reform_full = pd.concat([dynamic.reform_calc, getattr(dynamic.reform_records, 'WT')], axis=1)
    df_reform = df_reform_full
    num_units = df_base["WT2026"].sum()
    
    # take_home_base = dynamic.base_data[year]["aftertax_income"].sum()/num_units
    # take_home_reform = dynamic.reform_data[year]["aftertax_income"].sum()/num_units
    
    take_home_base = (df_base["aftertax_income"]*df_base["WT2026"]).sum()/num_units
    take_home_reform = (df_reform["aftertax_income"]*df_reform["WT2026"]).sum()/num_units
    
    out_per_unit = round(diff.loc['Difference', year]/num_units)
    take_home_increase = round(take_home_reform-take_home_base)
   
    output_i = {
        'Congressional district': local_name,
        'Change in tax revenues under OBBB ($ million)': f"{out:,d}",
        'Average change in tax liabilities under OBBB ($)': f"{out_per_unit:,d}",
        'Average change in take-home pay under OBBB ($)': f"{take_home_increase:,d}",
    }
    output_list.append(output_i)

df = pd.DataFrame.from_dict(output_list, orient='columns')

# %%
styled_df = df.style.set_caption("The Impact of OBBB on Congressional Districts in "+str(year)).set_table_styles([{
    'selector': 'caption',
    'props': [
        ('font-weight', 'bold'),
        ('font-size', '16px')
    ]
}])

# %%
styled_df
# Out:
# <style type="text/css">
# #T_f10d8 caption {
#   font-weight: bold;
#   font-size: 16px;
# }
# </style>
# <table id="T_f10d8">
#   <caption>The Impact of OBBB (for Four-Member Households) on Congressional Districts in 2026</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f10d8_level0_col0" class="col_heading level0 col0" >Congressional district</th>
#       <th id="T_f10d8_level0_col1" class="col_heading level0 col1" >Change in tax revenues under OBBB ($ million)</th>
#       <th id="T_f10d8_level0_col2" class="col_heading level0 col2" >Average change in tax liabilities under OBBB ($)</th>
#       <th id="T_f10d8_level0_col3" class="col_heading level0 col3" >Average change in take-home pay under OBBB ($)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f10d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f10d8_row0_col0" class="data row0 col0" >AK-00</td>
#       <td id="T_f10d8_row0_col1" class="data row0 col1" >-795</td>
#       <td id="T_f10d8_row0_col2" class="data row0 col2" >-1,878</td>
#       <td id="T_f10d8_row0_col3" class="data row0 col3" >3,152</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f10d8_row1_col0" class="data row1 col0" >AL-01</td>
#       <td id="T_f10d8_row1_col1" class="data row1 col1" >-603</td>
#       <td id="T_f10d8_row1_col2" class="data row1 col2" >-1,529</td>
#       <td id="T_f10d8_row1_col3" class="data row1 col3" >2,498</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f10d8_row2_col0" class="data row2 col0" >AL-02</td>
#       <td id="T_f10d8_row2_col1" class="data row2 col1" >-511</td>
#       <td id="T_f10d8_row2_col2" class="data row2 col2" >-1,335</td>
#       <td id="T_f10d8_row2_col3" class="data row2 col3" >2,111</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f10d8_row3_col0" class="data row3 col0" >AL-03</td>
#       <td id="T_f10d8_row3_col1" class="data row3 col1" >-510</td>
#       <td id="T_f10d8_row3_col2" class="data row3 col2" >-1,344</td>
#       <td id="T_f10d8_row3_col3" class="data row3 col3" >2,155</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f10d8_row4_col0" class="data row4 col0" >AL-04</td>
#       <td id="T_f10d8_row4_col1" class="data row4 col1" >-532</td>
#       <td id="T_f10d8_row4_col2" class="data row4 col2" >-1,428</td>
#       <td id="T_f10d8_row4_col3" class="data row4 col3" >2,236</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f10d8_row5_col0" class="data row5 col0" >AL-05</td>
#       <td id="T_f10d8_row5_col1" class="data row5 col1" >-661</td>
#       <td id="T_f10d8_row5_col2" class="data row5 col2" >-1,667</td>
#       <td id="T_f10d8_row5_col3" class="data row5 col3" >2,813</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f10d8_row6_col0" class="data row6 col0" >AL-06</td>
#       <td id="T_f10d8_row6_col1" class="data row6 col1" >-726</td>
#       <td id="T_f10d8_row6_col2" class="data row6 col2" >-1,916</td>
#       <td id="T_f10d8_row6_col3" class="data row6 col3" >3,592</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f10d8_row7_col0" class="data row7 col0" >AL-07</td>
#       <td id="T_f10d8_row7_col1" class="data row7 col1" >-422</td>
#       <td id="T_f10d8_row7_col2" class="data row7 col2" >-1,085</td>
#       <td id="T_f10d8_row7_col3" class="data row7 col3" >1,717</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f10d8_row8_col0" class="data row8 col0" >AR-01</td>
#       <td id="T_f10d8_row8_col1" class="data row8 col1" >-513</td>
#       <td id="T_f10d8_row8_col2" class="data row8 col2" >-1,314</td>
#       <td id="T_f10d8_row8_col3" class="data row8 col3" >2,045</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f10d8_row9_col0" class="data row9 col0" >AR-02</td>
#       <td id="T_f10d8_row9_col1" class="data row9 col1" >-617</td>
#       <td id="T_f10d8_row9_col2" class="data row9 col2" >-1,496</td>
#       <td id="T_f10d8_row9_col3" class="data row9 col3" >2,564</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f10d8_row10_col0" class="data row10 col0" >AR-03</td>
#       <td id="T_f10d8_row10_col1" class="data row10 col1" >-596</td>
#       <td id="T_f10d8_row10_col2" class="data row10 col2" >-1,457</td>
#       <td id="T_f10d8_row10_col3" class="data row10 col3" >2,831</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f10d8_row11_col0" class="data row11 col0" >AR-04</td>
#       <td id="T_f10d8_row11_col1" class="data row11 col1" >-511</td>
#       <td id="T_f10d8_row11_col2" class="data row11 col2" >-1,286</td>
#       <td id="T_f10d8_row11_col3" class="data row11 col3" >2,015</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f10d8_row12_col0" class="data row12 col0" >AZ-01</td>
#       <td id="T_f10d8_row12_col1" class="data row12 col1" >-909</td>
#       <td id="T_f10d8_row12_col2" class="data row12 col2" >-1,949</td>
#       <td id="T_f10d8_row12_col3" class="data row12 col3" >4,337</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f10d8_row13_col0" class="data row13 col0" >AZ-02</td>
#       <td id="T_f10d8_row13_col1" class="data row13 col1" >-646</td>
#       <td id="T_f10d8_row13_col2" class="data row13 col2" >-1,462</td>
#       <td id="T_f10d8_row13_col3" class="data row13 col3" >2,461</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f10d8_row14_col0" class="data row14 col0" >AZ-03</td>
#       <td id="T_f10d8_row14_col1" class="data row14 col1" >-479</td>
#       <td id="T_f10d8_row14_col2" class="data row14 col2" >-1,091</td>
#       <td id="T_f10d8_row14_col3" class="data row14 col3" >1,584</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f10d8_row15_col0" class="data row15 col0" >AZ-04</td>
#       <td id="T_f10d8_row15_col1" class="data row15 col1" >-808</td>
#       <td id="T_f10d8_row15_col2" class="data row15 col2" >-1,759</td>
#       <td id="T_f10d8_row15_col3" class="data row15 col3" >3,165</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f10d8_row16_col0" class="data row16 col0" >AZ-05</td>
#       <td id="T_f10d8_row16_col1" class="data row16 col1" >-839</td>
#       <td id="T_f10d8_row16_col2" class="data row16 col2" >-1,877</td>
#       <td id="T_f10d8_row16_col3" class="data row16 col3" >3,299</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f10d8_row17_col0" class="data row17 col0" >AZ-06</td>
#       <td id="T_f10d8_row17_col1" class="data row17 col1" >-684</td>
#       <td id="T_f10d8_row17_col2" class="data row17 col2" >-1,517</td>
#       <td id="T_f10d8_row17_col3" class="data row17 col3" >2,621</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f10d8_row18_col0" class="data row18 col0" >AZ-07</td>
#       <td id="T_f10d8_row18_col1" class="data row18 col1" >-560</td>
#       <td id="T_f10d8_row18_col2" class="data row18 col2" >-1,257</td>
#       <td id="T_f10d8_row18_col3" class="data row18 col3" >1,943</td>
#     </tr>
#     <tr>
#       <th id="T_f10d8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f10d8_row19_col0" class="data row19 col0" >AZ-08</td>
#       <td id="T_f10d

# %%
df.to_excel('OBBB_Localized_Impact.xlsx', index=False)
df.to_csv('OBBB_Localized_Impact.csv', index=False)
