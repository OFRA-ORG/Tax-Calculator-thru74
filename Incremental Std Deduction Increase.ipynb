# %%
# import sys
# # setting path
# sys.path.append('../')

from taxbrain.taxbrain import TaxBrain
from taxbrain import report

# %%
tcja_ext = "github://OFRA-ORG:Tax-Calculator-thru74@tcja/taxcalc/reforms/ext.json"

values1 = [
    15339.57 + 2000 * 1,
    30679.14 + 4000 * 1,
    15339.57 + 2000 * 1,
    22979.74 + 3000 * 1,
    30679.14 + 4000 * 1,
]

values2 = [
    15339.57 + 2000 * 2,
    30679.14 + 4000 * 2,
    15339.57 + 2000 * 2,
    22979.74 + 3000 * 2,
    30679.14 + 4000 * 2,
]

values3 = [
    15339.57 + 2000 * 3,
    30679.14 + 4000 * 3,
    15339.57 + 2000 * 3,
    22979.74 + 3000 * 3,
    30679.14 + 4000 * 3,
]

values4 = [
    15339.57 + 2000 * 4,
    30679.14 + 4000 * 4,
    15339.57 + 2000 * 4,
    22979.74 + 3000 * 4,
    30679.14 + 4000 * 4,
]

values5 = [
    15339.57 + 2000 * 5,
    30679.14 + 4000 * 5,
    15339.57 + 2000 * 5,
    22979.74 + 3000 * 5,
    30679.14 + 4000 * 5,
]

values6 = [
    15339.57 + 2000 * 6,
    30679.14 + 4000 * 6,
    15339.57 + 2000 * 6,
    22979.74 + 3000 * 6,
    30679.14 + 4000 * 6,
]

######

reform_std_1 = f"""
{{"STD": {{"2026": [{values1[0]},{values1[1]},{values1[2]},{values1[3]},{values1[4]}]}}}}
"""

reform_std_2 = f"""
{{"STD": {{"2026": [{values2[0]},{values2[1]},{values2[2]},{values2[3]},{values2[4]}]}}}}
"""

reform_std_3 = f"""
{{"STD": {{"2026": [{values3[0]},{values3[1]},{values3[2]},{values3[3]},{values3[4]}]}}}}
"""

reform_std_4 = f"""
{{"STD": {{"2026": [{values4[0]},{values4[1]},{values4[2]},{values4[3]},{values4[4]}]}}}}
"""

reform_std_5 = f"""
{{"STD": {{"2026": [{values5[0]},{values5[1]},{values5[2]},{values5[3]},{values5[4]}]}}}}
"""

reform_std_6 = f"""
{{"STD": {{"2026": [{values6[0]},{values6[1]},{values6[2]},{values6[3]},{values6[4]}]}}}}
"""

# reform_std_2 = """{
#     "STD": {"2026": [
#     15339.57+2000*2,
#     30679.14+4000*2,
#     15339.57+2000*2,
#     22979.74+3000*2,
#     30679.14+4000*2,
#     ]}
# }"""

# reform_std_3 = """{
#     "STD": {"2026": [
#     15339.57+2000*3,
#     30679.14+4000*3,
#     15339.57+2000*3,
#     22979.74+3000*3,
#     30679.14+4000*3,
#     ]}
# }"""

# reform_std_4 = """{
#     "STD": {"2026": [
#     15339.57+2000*4,
#     30679.14+4000*4,
#     15339.57+2000*4,
#     22979.74+3000*4,
#     30679.14+4000*4,
#     ]}
# }"""

# reform_std_5 = """{
#     "STD": {"2026": [
#     15339.57+2000*5,
#     30679.14+4000*5,
#     15339.57+2000*5,
#     22979.74+3000*5,
#     30679.14+4000*5,
#     ]}
# }"""

# reform_std_6 = """{
#     "STD": {"2026": [
#     15339.57+2000*6,
#     30679.14+4000*6,
#     15339.57+2000*6,
#     22979.74+3000*6,
#     30679.14+4000*6,
#     ]}
# }"""

# %%
reform_dict = {
    "tcja_ext": tcja_ext,
    "std_1": reform_std_1,
    "std_2": reform_std_2,
    "std_3": reform_std_3,
    "std_4": reform_std_4,
    "std_5": reform_std_5,
    "std_6": reform_std_6
}

# %%
dynamic = TaxBrain(2025, 2034, microdata="TMD", reform=reform_dict, stacked=True, behavior={"sub": 0.25, "cg": -3.45})
dynamic.run()

# %%
df = dynamic.stacked_table * 1e-9
df.to_csv('incremental std deduction increase.csv')

# %%
df
# Out:
#           2025        2026        2027        2028        2029        2030  \
# tcja_ext   0.0 -223.066405 -228.336550 -233.580972 -225.218800 -230.153917
# std_1      0.0  -47.057702  -48.638595  -50.672906  -52.354425  -53.997526
# std_2      0.0  -48.146673  -49.781184  -51.592027  -53.209778  -55.073207
# std_3      0.0  -47.595657  -49.614740  -51.265648  -53.170732  -54.674267
# std_4      0.0  -47.021170  -48.759809  -50.574456  -52.265726  -54.213698
# std_5      0.0  -45.623262  -47.702414  -49.208578  -51.387615  -52.891631
# std_6      0.0  -44.286399  -46.392284  -47.818637  -49.509298  -51.267471
# Total      0.0 -502.797268 -519.225576 -534.713224 -537.116375 -552.271717
#
#                 2031        2032        2033        2034    2025-2034
# tcja_ext -235.293744 -240.401069 -245.704223 -251.262609 -2113.018289
# std_1     -56.006370  -57.558246  -59.564601  -61.318118  -487.168488
# std_2     -57.349631  -59.473153  -61.120322  -62.838317  -498.584292
# ...
