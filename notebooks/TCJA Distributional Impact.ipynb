# %%
import os
import pandas as pd
from taxbrain.taxbrain import TaxBrain

# %%
reform_url = "github://PSLmodels:Tax-Calculator@master/taxcalc/reforms/ext.json"

# %%
dynamic = TaxBrain(2026, 2026, microdata="TMD", reform=reform_url, behavior={"sub": 0.25, "cg": -3.45})
dynamic.run()

# %%
dynamic.differences_table(2026, "weighted_deciles", tax_to_diff="iitax")
# Out:
#              count     tax_cut   perc_cut    tax_inc   perc_inc          mean  \
# 0-10n     3.052656    0.055694   1.824435   0.019397   0.635428    -24.920499
# 0-10z     9.548321    0.000000   0.000000   0.000000   0.000000      0.000000
# 0-10p     6.642492    0.124563   1.875252   0.000534   0.008041     -0.791021
# 10-20    19.256713    2.901774  15.068894   0.003709   0.019259    -11.686612
# 20-30    19.247413    8.389460  43.587469   0.168403   0.874939    -60.561167
# 30-40    19.253537   10.872675  56.471056   0.414208   2.151337   -160.834160
# 40-50    19.250639   14.465157  75.141180   1.068734   5.551683   -385.585105
# 50-60    19.250439   15.694537  81.528203   1.654726   8.595782   -633.902635
# 60-70    19.249734   16.371645  85.048685   2.254069  11.709610   -905.832057
# 70-80    19.249805   16.579360  86.127418   2.517009  13.075505  -1315.462030
# 80-90    19.251193   15.985457  83.036188   3.209241  16.670349  -1890.580118
# ...
