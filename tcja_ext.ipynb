# %%
from taxbrain.taxbrain import TaxBrain
from taxbrain import report

# %%
## corresponding to JCT's I.A.1
json1_rates = """{
    "II_rt1": {"2026": 0.10},
    "II_brk1": {"2026": [12170.98, 24341.94, 12170.98, 17353.27, 24341.94]},
    "PT_rt1": {"2026": 0.10},
    "PT_brk1": {"2026": [12170.98, 24341.94, 12170.98, 17353.27, 24341.94]},
    "II_rt2": {"2026": 0.12},
    "II_brk2": {"2026": [49483.44, 98966.89, 49483.44, 66214.83, 98966.89]},
    "PT_rt2": {"2026": 0.12},
    "PT_brk2": {"2026": [49483.44, 98966.89, 49483.44, 66214.83, 98966.89]},
    "II_rt3": {"2026": 0.22},
    "II_brk3": {"2026": [105511.38, 211022.75, 105511.38, 105481.77, 211022.75]},
    "PT_rt3": {"2026": 0.22},
    "PT_brk3": {"2026": [105511.38, 211022.75, 105511.38, 105481.77, 211022.75]},
    "II_rt4": {"2026": 0.24},
    "II_brk4": {"2026": [201428.14, 402856.25, 201428.14, 201428.14, 402856.25]},
    "PT_rt4": {"2026": 0.24},
    "PT_brk4": {"2026": [201428.14, 402856.25, 201428.14, 201428.14, 402856.25]},
    "II_rt5": {"2026": 0.32},
    "II_brk5": {"2026": [255797.72, 511595.46, 255797.72, 255797.72, 511595.46]},
    "PT_rt5": {"2026": 0.32},
    "PT_brk5": {"2026": [255797.72, 511595.46, 255797.72, 255797.72, 511595.46]},
    "II_rt6": {"2026": 0.35},
    "II_brk6": {"2026": [639523.94, 767393.2, 383696.6, 639523.94, 767393.2]},
    "PT_rt6": {"2026": 0.35},
    "PT_brk6": {"2026": [639523.94, 767393.2, 383696.6, 639523.94, 767393.2]},
    "II_rt7": {"2026": 0.37},
    "II_brk7": {"2026": [9e+99, 9e+99, 9e+99, 9e+99, 9e+99]},
    "PT_rt7": {"2026": 0.37},
    "PT_brk7": {"2026": [9e+99, 9e+99, 9e+99, 9e+99, 9e+99]}
}"""

## corresponding to JCT's I.A.2
json2_sd = """{
    "STD": {"2026": [15339.57, 30679.14, 15339.57, 22979.74, 30679.14]}
}"""

## corresponding to JCT's I.A.3
json3_personal_exemption = """{
    "II_em": {"2026": 0.00},
    "II_em_ps": {"2026": [9e+99, 9e+99, 9e+99, 9e+99, 9e+99]}
}"""

## corresponding to JCT's I.B.1
json4_qbid = """{
    "PT_qbid_rt": {"2026": 0.20},
    "PT_qbid_taxinc_thd": {"2026": [201428.14, 402856.25, 201428.14, 201428.14, 402856.25]},
    "PT_qbid_taxinc_gap": {"2026": [50000.0, 100000.0, 50000.0, 50000.0, 100000.0]},
    "PT_qbid_w2_wages_rt": {"2026": 0.50},
    "PT_qbid_alt_w2_wages_rt": {"2026": 0.25},
    "PT_qbid_alt_property_rt": {"2026": 0.03}
}"""

## corresponding to JCT's I.B.2
json5_excess_biz_loss = """{
   "ALD_BusinessLosses_c": {"2026": [319821.19, 639642.39, 319821.19, 319821.19, 639642.39]}
}"""

## corresponding to JCT's I.C.1
json6_ctc = """{
    "CTC_c": {"2026": 2000.00},
    "ACTC_c": {"2026": 1600.00},
    "CTC_ps": {"2026": [200000.0, 400000.0, 200000.0, 200000.0, 400000.0]},
    "ACTC_Income_thd": {"2026": 2500.00}
}"""

## corresponding to JCT's I.C.2
json7_odc = """{
    "ODC_c": {"2026": 500.00}
}"""

## corresponding to JCT's I.D.1 to I.D.3
json8_id = """{
    "ID_AllTaxes_c": {"2026": [10000.0, 10000.0, 5000.0, 10000.0, 10000.0]},
    "ID_Charity_crt_cash": {"2026": 0.60},
    "ID_Casualty_hc": {"2026": 1.00},
    "ID_Miscellaneous_hc": {"2026": 1.00},
    "ID_ps": {"2026": [9e+99, 9e+99, 9e+99, 9e+99, 9e+99]},
    "ID_prt": {"2026": 0.00},
    "ID_crt": {"2026": 1.00}
}"""

## JCT's I.D.4 and I.D.7 are minor and not modeled

## JCT's I.D.5 and I.D.6 don't seem to have a counterpart in the ext.json file

## JCT's I.E is minor and not modeled

## JCT's I.F doesn't seem to have a counterpart in the ext.json file

## corresponding to JCT's I.G
json9_amt = """{
    "AMT_em": {"2026": [89905.29, 139892.17, 69946.08, 89905.29, 139892.17]},
    "AMT_em_ps": {"2026": [639523.94, 1279047.88, 639523.94, 639523.94, 1279047.88]},
    "AMT_em_pe": {"2026": 939533.04}
}"""

## corresponding to JCT's II.E.1
json10_ald_domesticprod = """{
   "ALD_DomesticProduction_hc": {"2026": 1.00}
}"""

reform_dict = {
    "Brackets and rates change": json1_rates,
    "Standard deduction increase": json2_sd,
    "Personal exemption repeal": json3_personal_exemption,
    "QBID": json4_qbid,
    "Excell business losses deduction cap": json5_excess_biz_loss,
    "CTC increase": json6_ctc,
    "Other dependent credit": json7_odc,
    "Itemized deduction repeal": json8_id,
    "AMT change": json9_amt,
    "Domestic production deduction repeal": json10_ald_domesticprod
}

# %% [markdown]
# ### 1. Rev estimate without behavioral response

# %%
dynamic_min = TaxBrain(2026, 2035, microdata="TMD", reform=reform_dict, stacked=True, behavior={"sub": 0})
dynamic_min.run(num_workers=5)
dynamic_min.stacked_table * 1e-12
# Out:
#                                           2026      2027      2028      2029  \
# Brackets and rates change            -0.210698 -0.219340 -0.227975 -0.237124
# Standard deduction increase          -0.112651 -0.116103 -0.119314 -0.122690
# Personal exemption repeal             0.160319  0.165715  0.170731  0.175847
# QBID                                 -0.066794 -0.069330 -0.071838 -0.074494
# Excell business losses deduction cap  0.014326  0.014674  0.015108  0.015612
# CTC increase                         -0.080254 -0.081747 -0.083023 -0.084258
# Other dependent credit               -0.006789 -0.006852 -0.006902 -0.006940
# Itemized deduction repeal             0.071116  0.075620  0.080131  0.084701
# AMT change                           -0.059742 -0.062287 -0.064978 -0.067943
# Domestic production deduction repeal  0.005227  0.005454  0.005678  0.005910
# Total                                -0.285940 -0.294196 -0.302382 -0.311380
#
#                                           2030      2031      2032      2033  \
# Brackets and rates change            -0.246394 -0.255937 -0.265722 -0.275656
# Standard deduction increase          -0.126170 -0.129722 -0.133302 -0.136974
# Personal exemption repeal             0.181087  0.186455  0.191865  0.197368
# QBID                                 -0.077160 -0.079926 -0.082818 -0.085798
# Excell business losses deduction cap  0.016112  0.016647  0.017253  0.017862
# CTC increase                         -0.085442 -0.086557 -0.087620 -0.088625
# Other dependent credit               -0.006981 -0.007022 -0.007055 -0.007083
# Itemized deduction repeal             0.089565  0.094659  0.100021  0.105504
# AMT change                           -0.071051 -0.074299 -0.077628 -0.081019
# Domestic production deduction repeal  0.006154  0.006411  0.006680  0.006958
# Total                                -0.320281 -0.329292 -0.338326 -0.347462
#
#                                           2034      2035  2026-2035
# Brackets and rates change            -0.285774 -0.296158  -2.520779
# Standard deduction increase          -0.140717 -0.144533  -1.282178
# Personal exemption repeal             0.202934  0.208550   1.840871
# QBID                                 -0.088857 -0.092003  -0.789019
# Excell business losses deduction cap  0.018508  0.019165   0.165268
# CTC increase                         -0.089562 -0.090429  -0.857516
# Other dependent credit               -0.007101 -0.007112  -0.069836
# Itemized deduction repeal             0.111165  0.117095   0.929575
# AMT change                           -0.084496 -0.088119  -0.731562
# Domestic production deduction repeal  0.007245  0.007542   0.063260
# Total                                -0.356656 -0.366003  -3.251917

# %% [markdown]
# ### 2. Rev estimate mild behavioral response sub = 0.25

# %%
dynamic_med = TaxBrain(2026, 2035, microdata="TMD", reform=reform_dict, stacked=True, behavior={"sub": 0.25})
dynamic_med.run(num_workers=5)
dynamic_med.stacked_table * 1e-12
# Out:
#                                           2026      2027      2028      2029  \
# Brackets and rates change            -0.171812 -0.179257 -0.186106 -0.193847
# Standard deduction increase          -0.111017 -0.114218 -0.117673 -0.120941
# Personal exemption repeal             0.161494  0.167238  0.172652  0.178214
# QBID                                 -0.066844 -0.069378 -0.071858 -0.074564
# Excell business losses deduction cap  0.013877  0.014231  0.014653  0.015156
# CTC increase                         -0.080099 -0.081706 -0.083173 -0.084650
# Other dependent credit               -0.006868 -0.006946 -0.007020 -0.007084
# Itemized deduction repeal             0.071491  0.075930  0.080437  0.085042
# AMT change                           -0.044224 -0.045984 -0.047927 -0.049905
# Domestic production deduction repeal  0.005214  0.005459  0.005659  0.005877
# Total                                -0.228789 -0.234632 -0.240356 -0.246701
#
#                                           2030      2031      2032      2033  \
# Brackets and rates change            -0.201493 -0.209385 -0.217238 -0.225602
# Standard deduction increase          -0.123929 -0.128078 -0.131378 -0.134986
# Personal exemption repeal             0.183178  0.189129  0.194186  0.200105
# QBID                                 -0.077089 -0.079706 -0.082671 -0.085552
# Excell business losses deduction cap  0.015650  0.016173  0.016755  0.017351
# CTC increase                         -0.085994 -0.087346 -0.088489 -0.089727
# Other dependent credit               -0.007093 -0.007142 -0.007005 -0.007222
# Itemized deduction repeal             0.089707  0.094682  0.100162  0.105728
# AMT change                           -0.051981 -0.054098 -0.056522 -0.058858
# Domestic production deduction repeal  0.006121  0.006353  0.006586  0.006828
# Total                                -0.252924 -0.259419 -0.265614 -0.271934
#
#                                           2034      2035  2026-2035
# Brackets and rates change            -0.233670 -0.242740  -2.061151
# Standard deduction increase          -0.138685 -0.142308  -1.263212
# Personal exemption repeal             0.205478  0.211675   1.863349
# QBID                                 -0.088660 -0.091735  -0.788058
# Excell business losses deduction cap  0.017986  0.018626   0.160458
# CTC increase                         -0.090812 -0.091835  -0.863831
# Other dependent credit               -0.007009 -0.007290  -0.070679
# Itemized deduction repeal             0.111574  0.117421   0.932175
# AMT change                           -0.061266 -0.063934  -0.534699
# Domestic production deduction repeal  0.007110  0.007409   0.062617
# Total                                -0.277953 -0.284710  -2.563030

# %% [markdown]
# ### 3. Rev estimate larger behavioral response sub = 0.5

# %%
dynamic_max = TaxBrain(2026, 2035, microdata="TMD", reform=reform_dict, stacked=True, behavior={"sub": 0.5})
dynamic_max.run(num_workers=5)
dynamic_max.stacked_table * 1e-12
# Out:
#                                           2026      2027      2028      2029  \
# Brackets and rates change            -0.131960 -0.138142 -0.143156 -0.149486
# Standard deduction increase          -0.108415 -0.111274 -0.114980 -0.118077
# Personal exemption repeal             0.161779  0.167844  0.173672  0.179657
# QBID                                 -0.066234 -0.068766 -0.071210 -0.073936
# Excell business losses deduction cap  0.013492  0.013840  0.014248  0.014749
# CTC increase                         -0.079880 -0.081633 -0.083275 -0.085000
# Other dependent credit               -0.006939 -0.007027 -0.007121 -0.007213
# Itemized deduction repeal             0.071756  0.076171  0.080704  0.085323
# AMT change                           -0.029222 -0.030187 -0.031401 -0.032408
# Domestic production deduction repeal  0.005188  0.005453  0.005633  0.005834
# Total                                -0.170434 -0.173722 -0.176886 -0.180557
#
#                                           2030      2031      2032      2033  \
# Brackets and rates change            -0.155445 -0.161593 -0.167511 -0.174237
# Standard deduction increase          -0.120488 -0.125307 -0.128412 -0.131882
# Personal exemption repeal             0.184244  0.190856  0.195707  0.201972
# QBID                                 -0.076290 -0.078766 -0.081787 -0.084489
# Excell business losses deduction cap  0.015238  0.015752  0.016310  0.016896
# CTC increase                         -0.086489 -0.088089 -0.089318 -0.090788
# Other dependent credit               -0.007197 -0.007257 -0.006962 -0.007350
# Itemized deduction repeal             0.089775  0.094587  0.100202  0.105780
# AMT change                           -0.033499 -0.034494 -0.036046 -0.037415
# Domestic production deduction repeal  0.006077  0.006289  0.006483  0.006697
# Total                                -0.184074 -0.188022 -0.191334 -0.194816
#
#                                           2034      2035  2026-2035
# Brackets and rates change            -0.180226 -0.187897  -1.589653
# Standard deduction increase          -0.135523 -0.139037  -1.233394
# Personal exemption repeal             0.207139  0.214064   1.876933
# QBID                                 -0.087581 -0.090555  -0.779615
# Excell business losses deduction cap  0.017524  0.018145   0.156194
# CTC increase                         -0.092020 -0.093275  -0.869768
# Other dependent credit               -0.006893 -0.007450  -0.071411
# Itemized deduction repeal             0.111812  0.117649   0.933760
# AMT change                           -0.038843 -0.040711  -0.344226
# Domestic production deduction repeal  0.006970  0.007283   0.061908
# Total                                -0.197641 -0.201784  -1.859271
