# %%
# import sys
# # setting path
# sys.path.append('../')

from taxbrain.taxbrain import TaxBrain
from taxbrain import report

# %%
tcja_ext = "github://OFRA-ORG:Tax-Calculator-thru74@tcja/taxcalc/reforms/ext.json"

######

reform_rt1_1 = """{
    "II_rt1": {"2026": 0.09},
    "PT_rt1": {"2026": 0.09}
}"""

reform_rt1_2 = """{
    "II_rt1": {"2026": 0.08},
    "PT_rt1": {"2026": 0.08}
}"""

reform_rt1_3 = """{
    "II_rt1": {"2026": 0.07},
    "PT_rt1": {"2026": 0.07}
}"""

reform_rt1_4 = """{
    "II_rt1": {"2026": 0.06},
    "PT_rt1": {"2026": 0.06}
}"""

reform_rt1_5 = """{
    "II_rt1": {"2026": 0.05},
    "PT_rt1": {"2026": 0.05}
}"""

reform_rt1_6 = """{
    "II_rt1": {"2026": 0.04},
    "PT_rt1": {"2026": 0.04}
}"""

reform_rt1_7 = """{
    "II_rt1": {"2026": 0.03},
    "PT_rt1": {"2026": 0.03}
}"""

reform_rt1_8 = """{
    "II_rt1": {"2026": 0.02},
    "PT_rt1": {"2026": 0.02}
}"""

reform_rt1_9 = """{
    "II_rt1": {"2026": 0.01},
    "PT_rt1": {"2026": 0.01}
}"""

reform_rt1_10 = """{
    "II_rt1": {"2026": 0},
    "PT_rt1": {"2026": 0}
}"""

######

reform_rt2_1 = """{
    "II_rt2": {"2026": 0.11},
    "PT_rt2": {"2026": 0.11}
}"""

reform_rt2_2 = """{
    "II_rt2": {"2026": 0.10},
    "PT_rt2": {"2026": 0.10}
}"""

# %%
reform_dict1 = {
    "tcja_ext": tcja_ext,
    "rt1_1": reform_rt1_1,
    "rt1_2": reform_rt1_2,
    "rt1_3": reform_rt1_3,
    "rt1_4": reform_rt1_4,
    "rt1_5": reform_rt1_5,
    "rt1_6": reform_rt1_6,
    "rt1_7": reform_rt1_7,
    "rt1_8": reform_rt1_8,
    "rt1_9": reform_rt1_9,
    "rt1_10": reform_rt1_10
}

reform_dict2 = {
    "tcja_ext": tcja_ext,
    "rt2_1": reform_rt2_1,
    "rt2_2": reform_rt2_2
}

# %%
dynamic_1 = TaxBrain(2025, 2034, microdata="TMD", reform=reform_dict1, stacked=True, behavior={"sub": 0.25, "cg": -3.45})
dynamic_1.run()

# %%
df1 = dynamic_1.stacked_table * 1e-9
df1.to_csv('incremental rate reduction 1.csv')

# %%
df1
# Out:
#           2025        2026        2027        2028        2029        2030  \
# tcja_ext   0.0 -220.185895 -225.107444 -230.361752 -221.756171 -226.357460
# rt1_1      0.0  -20.251095  -21.015402  -21.739175  -22.450437  -23.218750
# rt1_2      0.0  -20.188890  -20.666562  -21.680746  -22.389516  -22.872844
